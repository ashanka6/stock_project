# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt  
import seaborn as sns
import yfinance as yf  
# imports yahoo finance to get stock data 

from bs4 import BeautifulSoup 
import requests 
# imports beautiful soup to scrape data from the web 
import time 
from tqdm import tqdm 
# imports time and tqdm for progress tracking during web scraping 

from datetime import datetime, timedelta
import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix
from sklearn.model_selection import TimeSeriesSplit

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Step 1: Fetch S&P 500 tickers from Wikipedia

def get_sp500_tickers():
    """Scrape S&P 500 tickers from Wikipedia using robust selectors."""
    url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
    }
    response = requests.get(url, headers=headers)
    response.raise_for_status()
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Try id='constituents' first, then class='wikitable sortable' as fallback
    table = soup.find('table', {'id': 'constituents'})
    if table is None:
        table = soup.find('table', {'class': 'wikitable sortable'})
    if table is None:
        raise RuntimeError('Could not locate S&P 500 table on Wikipedia.')
    
    raw_tickers = []
    for row in table.find_all('tr')[1:]:  # Skip header row
        cols = row.find_all('td')
        if not cols:
            continue
        ticker = cols[0].text.strip()
        if ticker:
            raw_tickers.append(ticker)
    
    # Clean tickers: replace '.' with '-' (e.g., BRK.B -> BRK-B)
    # Skip tickers with '/' (preferred shares)
    cleaned_tickers = []
    for t in raw_tickers:
        t_clean = t.replace('.', '-')
        if '/' in t_clean:
            continue
        cleaned_tickers.append(t_clean)
    
    print(f"Found {len(raw_tickers)} raw tickers. After cleaning: {len(cleaned_tickers)} remain.")
    return cleaned_tickers

# %%
# Step 2: Collect historical data (quarterly fundamentals + monthly prices)

def get_fundamentals(ticker, years_back=5):
    """
    Retrieve annual fundamentals (more reliable than quarterly) and 
    repeat them quarterly for alignment. This is a pragmatic trade-off.
    """
    try:
        stock = yf.Ticker(ticker)
        # Annual financials
        annual_fin = stock.financials.T  # rows = fiscal years
        annual_balance = stock.balance_sheet.T
        if annual_fin.empty:
            return None
        
        # Use the last 'years_back' years
        cutoff = pd.Timestamp.now() - pd.DateOffset(years=years_back)
        annual_fin = annual_fin[annual_fin.index >= cutoff]
        
        # For simplicity, we'll create quarterly rows by repeating annual data each quarter
        # In a real project you'd interpolate or use quarterly reports, but this gets us running.
        return {'financials': annual_fin, 'balance': annual_balance}
    except Exception as e:
        print(f"Failed to get fundamentals for {ticker}: {e}")
        return None

def get_price_returns(ticker, start_date, end_date):
    """Fetch monthly adjusted close prices (resampled end-of-month).
    Returns a monthly price series (Adj Close) or None on failure.
    """
    try:
        data = yf.download(ticker, start=start_date, end=end_date, interval='1mo', progress=False)
        if data.empty:
            return None
        # Use adjusted close to incorporate dividends; take last valid value each month
        if 'Adj Close' in data.columns:
            prices = data['Adj Close'].resample('M').last()
        elif 'Close' in data.columns:
            prices = data['Close'].resample('M').last()
        else:
            # some yfinance responses may nest columns; try to locate a price-like column
            try:
                prices = data.iloc[:, 0].resample('M').last()
            except Exception:
                return None
        if prices.empty:
            return None
        return prices
    except Exception as e:
        print(f"Failed to get prices for {ticker}: {e}")
        return None

# %%
# Step 3: Compute valuation & growth metrics per quarter 

def compute_metrics(fund_data, price_at_quarter_end, ticker):
    """Compute valuation metrics from annual data (simple approach)."""
    if fund_data is None:
        return pd.Series(dtype=float)
    
    fin = fund_data.get('financials')
    if fin is None or fin.empty:
        return pd.Series(dtype=float)
    
    # Use most recent year's Net Income and Revenue
    try:
        net_income = fin['Net Income'].iloc[0]  # most recent year
        revenue = fin['Total Revenue'].iloc[0]
    except Exception:
        return pd.Series(dtype=float)
    
    # Use a fallback shares value instead of additional yfinance info calls.
    shares = 1e9
    dividend_yield = np.nan
    
    if shares is None or shares <= 0:
        shares = 1e9
    
    trailing_pe = price_at_quarter_end / (net_income / shares) if net_income > 0 else np.nan
    # Dummy forward PE (use trailing as placeholder)
    forward_pe = trailing_pe
    peg = np.nan
    earnings_growth = np.nan
    revenue_growth = np.nan
    
    metrics = pd.Series({
        'trailing_pe': trailing_pe,
        'forward_pe': forward_pe,
        'peg': peg,
        'dividend_yield': dividend_yield,
        'earnings_growth': earnings_growth,
        'revenue_growth': revenue_growth
    })
    return metrics

# %%
# Step 4: Build the master dataset: stock-quarter observations 

def build_dataset(tickers, start_date, end_date, years_fund=5):
    all_rows = []
    # Get benchmark returns once
    benchmark_returns = get_price_returns('SPY', start_date, end_date)
    if benchmark_returns is None:
        print("Failed to get benchmark SPY returns. Aborting dataset build.")
        return pd.DataFrame()
    
    for ticker in tickers:
        print(f"Processing {ticker}...", end=' ')
        # Get fundamentals
        fund_data = get_fundamentals(ticker, years_back=years_fund)
        if fund_data is None:
            print("No fundamentals, skipping.")
            continue
        
        # Get price series
        prices = get_price_returns(ticker, start_date, end_date)
        if prices is None or prices.empty:
            print("No price data, skipping.")
            continue
        
        # We'll create quarterly synthetic timestamps (each quarter end)
        # For simplicity, use the index of benchmark_returns as candidate quarters
        quarters = benchmark_returns.index.to_period('Q').unique().to_timestamp(how='end')
        quarters = [q for q in quarters if start_date <= q <= end_date]
        
        for q_date in quarters:
            # Price at quarter end
            price_at_q = prices.asof(q_date)
            # handle possible scalar or array-like return from asof
            def is_missing(x):
                try:
                    m = pd.isna(x)
                    if hasattr(m, 'all'):
                        return bool(m.all())
                    return bool(m)
                except Exception:
                    return True

            def extract_numeric(x):
                """Return a single float for scalar or Series-like x (use last non-NA)."""
                if x is None:
                    return np.nan
                try:
                    if hasattr(x, 'dropna'):
                        s = x.dropna()
                        if len(s) == 0:
                            return np.nan
                        return float(s.iloc[-1])
                except Exception:
                    pass
                try:
                    return float(x)
                except Exception:
                    return np.nan

            if is_missing(price_at_q):
                continue
            price_at_q = extract_numeric(price_at_q)
            
            # Compute metrics (using annual fundamentals repeated)
            metrics = compute_metrics(fund_data, price_at_q, ticker)
            if metrics.empty:
                continue
            
            # Future 6M and 12M returns
            future_6m = q_date + pd.DateOffset(months=6)
            future_12m = q_date + pd.DateOffset(months=12)
            price_6m = prices.asof(future_6m)
            price_12m = prices.asof(future_12m)
            bench_price_6m = benchmark_returns.asof(future_6m)
            bench_price_12m = benchmark_returns.asof(future_12m)
            bench_price_now = benchmark_returns.asof(q_date)

            # Extract numeric scalars for arithmetic
            price_6m = extract_numeric(price_6m)
            price_12m = extract_numeric(price_12m)
            bench_price_6m = extract_numeric(bench_price_6m)
            bench_price_12m = extract_numeric(bench_price_12m)
            bench_price_now = extract_numeric(bench_price_now)
            
            if any(is_missing(v) for v in [price_6m, price_12m, bench_price_6m, bench_price_12m, bench_price_now]):
                continue
            
            stock_ret_6m = (price_6m / price_at_q) - 1
            stock_ret_12m = (price_12m / price_at_q) - 1
            bench_ret_6m = (bench_price_6m / bench_price_now) - 1
            bench_ret_12m = (bench_price_12m / bench_price_now) - 1
            
            excess_6m = stock_ret_6m - bench_ret_6m
            excess_12m = stock_ret_12m - bench_ret_12m
            
            row = metrics.to_dict()
            row['ticker'] = ticker
            row['quarter'] = q_date
            row['excess_6m'] = excess_6m
            row['excess_12m'] = excess_12m
            row['target_6m'] = int(excess_6m > 0)
            row['target_12m'] = int(excess_12m > 0)
            
            all_rows.append(row)
        print(f"done ({len([r for r in all_rows if r['ticker']==ticker])} quarters).")
    
    if not all_rows:
        return pd.DataFrame()
    return pd.DataFrame(all_rows)

# %%
# Step 5: Data cleaning and feature engineering  

def clean_data(df):
    """Remove extreme outliers, fill missing values, and create final feature set.

    This is tolerant: only `trailing_pe` and `forward_pe` are required. Other
    features are filled with medians (or 0) so we don't drop most rows.
    """
    if df is None or df.empty:
        return pd.DataFrame(), []

    # Require only the core metrics needed for clustering
    required_cols = ['trailing_pe', 'forward_pe']
    df_clean = df.dropna(subset=required_cols).copy()

    # Ensure optional columns exist
    for c in ['peg', 'dividend_yield', 'earnings_growth', 'revenue_growth']:
        if c not in df_clean.columns:
            df_clean[c] = np.nan

    # Fill missing optional features with median or 0.0 fallback
    for c in ['peg', 'dividend_yield', 'earnings_growth', 'revenue_growth']:
        med = df_clean[c].median()
        if pd.isna(med):
            med = 0.0
        df_clean[c] = df_clean[c].fillna(med)

    # Cap extreme values (1st and 99th percentiles)
    clip_cols = ['trailing_pe', 'forward_pe', 'peg', 'dividend_yield', 'earnings_growth', 'revenue_growth']
    for col in clip_cols:
        lower = df_clean[col].quantile(0.01)
        upper = df_clean[col].quantile(0.99)
        df_clean[col] = df_clean[col].clip(lower, upper)

    # Log transform skewed features (guard non-positive values)
    df_clean['log_trailing_pe'] = np.log1p(df_clean['trailing_pe'].clip(lower=0))
    df_clean['log_forward_pe'] = np.log1p(df_clean['forward_pe'].clip(lower=0))

    # Features for clustering and modeling
    feature_cols = ['log_trailing_pe', 'log_forward_pe', 'peg', 'dividend_yield', 'earnings_growth', 'revenue_growth']
    return df_clean, feature_cols

# %%
# Step 6: K-Means clustering + Elbow Method from Module 4   

def perform_clustering(df, feature_cols, n_clusters_range=range(2,11)):
    """Apply k-means, choose optimal clusters via elbow method, return cluster labels."""
    if df is None or df.empty:
        print("perform_clustering: empty dataframe provided; skipping clustering.")
        return df, None, None

    X = df[feature_cols].copy()
    if X.shape[0] == 0:
        print("perform_clustering: no rows available for features; skipping.")
        return df, None, None

    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    
    inertias = []
    for k in n_clusters_range:
        kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
        kmeans.fit(X_scaled)
        inertias.append(kmeans.inertia_)
    
    # Plot elbow
    plt.figure(figsize=(8,4))
    plt.plot(n_clusters_range, inertias, 'bo-')
    plt.xlabel('Number of clusters')
    plt.ylabel('Inertia')
    plt.title('Elbow Method for Optimal k')
    plt.show()
    
    # Choose k (manually or using knee heuristic). For demo, use k=4 if elbow unclear.
    # We'll let user see plot; programmatically pick where inertia decrease slows
    diffs = np.diff(inertias)
    k_opt = n_clusters_range[np.argmin(diffs) + 1]  # simple knee
    
    final_kmeans = KMeans(n_clusters=k_opt, random_state=42, n_init=10)
    df['cluster'] = final_kmeans.fit_predict(X_scaled)
    
    print(f"Optimal clusters: {k_opt}")
    return df, final_kmeans, scaler

# %%
# Step 7: Logistic Regression with walk-forward validation from Module 6 

def walk_forward_logistic(df, target_col, feature_cols, cluster_col='cluster', min_train_quarters=12):
    """
    Time-series cross-validation: train on expanding window, predict next quarter.
    Returns evaluation metrics and a DataFrame with predicted probabilities.
    """
    # Guard empty input
    if df is None or df.empty:
        print('walk_forward_logistic: empty dataframe provided; skipping walk-forward.')
        return pd.DataFrame(), {}

    # Sort by quarter
    df_sorted = df.sort_values('quarter').reset_index(drop=True)
    quarters = df_sorted['quarter'].unique()
    if len(quarters) <= min_train_quarters:
        print("Not enough quarters for walk-forward validation. Need more historical quarters.")
        return pd.DataFrame(), {}
    predictions = []
    true_labels = []
    
    # Add cluster dummies to features
    cluster_dummies = pd.get_dummies(df_sorted[cluster_col], prefix='cluster')
    X_full = pd.concat([df_sorted[feature_cols], cluster_dummies], axis=1)
    y_full = df_sorted[target_col]
    
    tscv = TimeSeriesSplit(n_splits=len(quarters) - min_train_quarters)
    for train_idx, test_idx in tscv.split(quarters):
        train_quarters = quarters[train_idx]
        test_quarter = quarters[test_idx[0]]  # predict only next quarter
        
        train_mask = df_sorted['quarter'].isin(train_quarters)
        test_mask = df_sorted['quarter'] == test_quarter
        
        X_train = X_full[train_mask]
        y_train = y_full[train_mask]
        X_test = X_full[test_mask]
        y_test = y_full[test_mask]
        
        if len(y_train) == 0 or len(y_test) == 0:
            continue
        
        # Handle class imbalance with class_weight
        model = LogisticRegression(class_weight='balanced', max_iter=1000, random_state=42)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        y_proba = model.predict_proba(X_test)[:, 1]
        
        # Store for final ranking
        temp = df_sorted[test_mask].copy()
        temp['pred_proba'] = y_proba
        predictions.append(temp)
        true_labels.extend(y_test)
        
        # Print quarterly performance
        acc = accuracy_score(y_test, y_pred)
        print(f"Test quarter {test_quarter}: Accuracy = {acc:.3f}")
    
    # Overall metrics
    all_preds = np.concatenate([p['pred_proba'].values for p in predictions])
    all_true = np.array(true_labels)
    final_pred_class = (all_preds >= 0.5).astype(int)
    
    metrics = {
        'accuracy': accuracy_score(all_true, final_pred_class),
        'precision': precision_score(all_true, final_pred_class, zero_division=0),
        'recall': recall_score(all_true, final_pred_class, zero_division=0),
        'f1': f1_score(all_true, final_pred_class, zero_division=0),
        'roc_auc': roc_auc_score(all_true, all_preds)
    }
    
    # Confusion matrix
    cm = confusion_matrix(all_true, final_pred_class)
    plt.figure(figsize=(5,4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title('Confusion Matrix (Walk-Forward)')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()
    
    return pd.concat(predictions, ignore_index=True), metrics

# %%
# Step 8: Final ranking for most recent quarter  

def produce_ranking(pred_df, df_original, feature_cols, cluster_col='cluster'):
    """For the most recent quarter in predictions, rank stocks in each cluster by predicted probability."""
    latest_quarter = pred_df['quarter'].max()
    latest = pred_df[pred_df['quarter'] == latest_quarter].copy()

    # Drop any existing cluster column to avoid duplicate columns during merge
    latest = latest.drop(columns=[cluster_col], errors='ignore')

    # Merge back original cluster labels (avoid attempting to select feature columns
    # that may not exist in `df_original`). We'll safely pick display columns later.
    latest = latest.merge(df_original[['ticker', 'quarter', cluster_col]],
                          on=['ticker', 'quarter'], how='left')

    # Sort within each cluster
    ranking = latest.sort_values([cluster_col, 'pred_proba'], ascending=[True, False])
    # Safely select display columns if present
    base_cols = [cluster_col, 'ticker', 'pred_proba']
    extra = [c for c in ['trailing_pe', 'forward_pe', 'peg', 'dividend_yield'] if c in ranking.columns]
    ranking = ranking[base_cols + extra]
    return ranking, latest_quarter

# %%
# Step 9: Main execution  

def main():
    print("Step 1: Fetch S&P 500 tickers...")
    tickers = get_sp500_tickers()
    print(f"Retrieved {len(tickers)} tickers.")
    
    # Define date range: last 5 years + 1 year for future returns
    end_date = datetime.today()
    start_date = end_date - pd.DateOffset(years=6)  # extra year for returns
    print(f"Data range: {start_date.date()} to {end_date.date()}")
    
    print("Step 2: Building dataset (this will take a while)...")
    df = build_dataset(tickers, start_date, end_date)
    print(f"Raw dataset shape: {df.shape}")
    
    print("Step 3: Cleaning data...")
    df_clean, feature_cols = clean_data(df)
    print(f"After cleaning: {df_clean.shape}")
    
    print("Step 4: K-means clustering...")
    df_clustered, kmeans_model, scaler = perform_clustering(df_clean, feature_cols)
    
    print("Step 5: Walk-forward logistic regression (predicting 6-month excess return)...")
    pred_df, metrics = walk_forward_logistic(df_clustered, target_col='target_6m', feature_cols=feature_cols)
    print("Model evaluation:")
    for k, v in metrics.items():
        print(f"  {k}: {v:.3f}")
    
    print("Step 6: Generate cluster-aware ranking for most recent quarter...")
    ranking, latest_q = produce_ranking(pred_df, df_clustered, feature_cols)
    print(f"\nTop 5 stocks per cluster (quarter = {latest_q.date()}):")
    for cluster_id in ranking['cluster'].unique():
        print(f"\nCluster {cluster_id}:")
        print(ranking[ranking['cluster'] == cluster_id][['ticker', 'pred_proba', 'trailing_pe']].head(5).to_string(index=False))
    
    # Save ranking to CSV
    ranking.to_csv('stock_ranking_latest_quarter.csv', index=False)
    print("\nRanking saved to 'stock_ranking_latest_quarter.csv'")
    
    # Optional: Save full dataset with clusters and predictions
    df_clustered.to_csv('full_dataset_with_clusters.csv', index=False)
    print("Full dataset saved to 'full_dataset_with_clusters.csv'")
    
    return df_clustered, pred_df, ranking, metrics
 
if __name__ == "__main__":
    main()
# Out:
# Step 1: Fetch S&P 500 tickers...
# Found 503 raw tickers. After cleaning: 503 remain.
# Retrieved 503 tickers.
# Data range: 2020-05-15 to 2026-05-15
# Step 2: Building dataset (this will take a while)...
# Processing MMM... done (24 quarters).
# Processing AOS... done (24 quarters).
# Processing ABT... done (24 quarters).
# Processing ABBV... done (24 quarters).
# Processing ACN... done (24 quarters).
# Processing ADBE... done (24 quarters).
# Processing AMD... done (24 quarters).
# Processing AES... done (24 quarters).
# Processing AFL... done (24 quarters).
# Processing A... done (24 quarters).
# Processing APD... done (24 quarters).
# Processing ABNB... done (22 quarters).
# Processing AKAM... done (24 quarters).
# Processing ALB... done (24 quarters).
# Processing ARE... done (24 quarters).
# Processing ALGN... done (24 quarters).
# Processing ALLE... done (24 quarters).
# Processing LNT... done (24 quarters).
# Processing ALL... done (24 quarters).
# Processing GOOGL... done (24 quarters).
# Processing GOOG... done (24 quarters).
# Processing MO... done (24 quarters).
# Processing AMZN... done (24 quarters).
# Processing AMCR... done (24 quarters).
# Processing AEE... done (0 quarters).
# Processing AEP... done (24 quarters).
# Processing AXP... done (24 quarters).
# Processing AIG... done (24 quarters).
# Processing AMT... done (24 quarters).
# Processing AWK... done (24 quarters).
# Processing AMP... done (24 quarters).
# Processing AME... done (24 quarters).
# Processing AMGN... done (24 quarters).
# Processing APH... done (24 quarters).
# Processing ADI... done (24 quarters).
# Processing AON... done (24 quarters).
# Processing APA... done (24 quarters).
# Processing APO... done (24 quarters).
# Processing AAPL... done (24 quarters).
# Processing AMAT... done (24 quarters).
# Processing APP... done (20 quarters).
# Processing APTV... done (24 quarters).
# Processing ACGL... done (24 quarters).
# Processing ADM... done (24 quarters).
# Processing ARES... done (24 quarters).
# Processing ANET... done (24 quarters).
# Processing AJG... done (24 quarters).
# Processing AIZ... done (24 quarters).
# Processing T... done (24 quarters).
# Processing ATO... done (24 quarters).
# Processing ADSK... done (24 quarters).
# Processing ADP... done (24 quarters).
# Processing AZO... done (24 quarters).
# Processing AVB... done (24 quarters).
# Processing AVY... done (24 quarters).
# Processing AXON... done (24 quarters).
# Processing BKR... done (24 quarters).
# Processing BALL... done (24 quarters).
# Processing BAC... done (24 quarters).
# Processing BAX... done (24 quarters).
# Processing BDX... done (24 quarters).
# Processing BRK-B... done (24 quarters).
# Processing BBY... done (24 quarters).
# Processing TECH... done (24 quarters).
# Processing BIIB... done (24 quarters).
# Processing BLK... done (24 quarters).
# Processing BX... done (24 quarters).
# Processing XYZ... done (24 quarters).
# Processing BK... done (24 quarters).
# Processing BA... done (24 quarters).
# Processing BKNG... done (24 quarters).
# Processing BSX... done (24 quarters).
# Processing BMY... done (24 quarters).
# Processing AVGO... done (24 quarters).
# Processing BR... done (24 quarters).
# Processing BRO... done (24 quarters).
# Processing BF-B... done (24 quarters).
# Processing BLDR... done (24 quarters).
# Processing BG... done (24 quarters).
# Processing BXP... done (24 quarters).
# Processing CHRW... done (24 quarters).
# Processing CDNS... done (24 quarters).
# Processing CPT... done (24 quarters).
# Processing CPB... done (24 quarters).
# Processing COF... done (24 quarters).
# Processing CAH... done (24 quarters).
# Processing CCL... done (24 quarters).
# Processing CARR... done (24 quarters).
# Processing CVNA... done (24 quarters).
# Processing CASY... done (24 quarters).
# Processing CAT... done (24 quarters).
# Processing CBOE... done (24 quarters).
# Processing CBRE... done (24 quarters).
# Processing CDW... done (24 quarters).
# Processing COR... done (24 quarters).
# Processing CNC... done (24 quarters).
# Processing CNP... done (24 quarters).
# Processing CF... done (24 quarters).
# Processing CRL... done (24 quarters).
# Processing SCHW... done (24 quarters).
# Processing CHTR... done (24 quarters).
# Processing CVX... done (24 quarters).
# Processing CMG... done (24 quarters).
# Processing CB... done (24 quarters).
# Processing CHD... done (24 quarters).
# Processing CIEN... done (24 quarters).
# Processing CI... done (24 quarters).
# Processing CINF... done (24 quarters).
# Processing CTAS... done (24 quarters).
# Processing CSCO... done (24 quarters).
# Processing C... done (24 quarters).
# Processing CFG... done (24 quarters).
# Processing CLX... done (24 quarters).
# Processing CME... done (24 quarters).
# Processing CMS... done (24 quarters).
# Processing KO... done (24 quarters).
# Processing CTSH... done (24 quarters).
# Processing COHR... done (24 quarters).
# Processing COIN... done (20 quarters).
# Processing CL... done (24 quarters).
# Processing CMCSA... done (24 quarters).
# Processing FIX... done (24 quarters).
# Processing CAG... done (24 quarters).
# Processing COP... done (24 quarters).
# Processing ED... done (24 quarters).
# Processing STZ... done (24 quarters).
# Processing CEG... done (17 quarters).
# Processing COO... done (24 quarters).
# Processing CPRT... done (24 quarters).
# Processing GLW... done (24 quarters).
# Processing CPAY... done (24 quarters).
# Processing CTVA... done (24 quarters).
# Processing CSGP... done (24 quarters).
# Processing COST... done (24 quarters).
# Processing CRH... done (24 quarters).
# Processing CRWD... done (24 quarters).
# Processing CCI... done (24 quarters).
# Processing CSX... done (24 quarters).
# Processing CMI... done (24 quarters).
# Processing CVS... done (24 quarters).
# Processing DHR... done (24 quarters).
# Processing DRI... done (24 quarters).
# Processing DDOG... done (24 quarters).
# Processing DVA... done (24 quarters).
# Processing DECK... done (24 quarters).
# Processing DE... done (24 quarters).
# Processing DELL... done (24 quarters).
# Processing DAL... done (24 quarters).
# Processing DVN... done (24 quarters).
# Processing DXCM... done (24 quarters).
# Processing FANG... done (24 quarters).
# Processing DLR... done (24 quarters).
# Processing DG... done (24 quarters).
# Processing DLTR... done (24 quarters).
# Processing D... done (24 quarters).
# Processing DPZ... done (24 quarters).
# Processing DASH... done (22 quarters).
# Processing DOV... done (24 quarters).
# Processing DOW... done (24 quarters).
# Processing DHI... done (24 quarters).
# Processing DTE... done (24 quarters).
# Processing DUK... done (24 quarters).
# Processing DD... done (24 quarters).
# Processing ETN... done (24 quarters).
# Processing EBAY... done (24 quarters).
# Processing SATS... done (24 quarters).
# Processing ECL... done (24 quarters).
# Processing EIX... done (24 quarters).
# Processing EW... done (24 quarters).
# Processing EA... done (24 quarters).
# Processing ELV... done (24 quarters).
# Processing EME... done (24 quarters).
# Processing EMR... done (24 quarters).
# Processing ETR... done (24 quarters).
# Processing EOG... done (24 quarters).
# Processing EPAM... done (24 quarters).
# Processing EQT... done (24 quarters).
# Processing EFX... done (24 quarters).
# Processing EQIX... done (24 quarters).
# Processing EQR... done (24 quarters).
# Processing ERIE... done (24 quarters).
# Processing ESS... done (24 quarters).
# Processing EL... done (24 quarters).
# Processing EG... done (24 quarters).
# Processing EVRG... done (24 quarters).
# Processing ES... done (24 quarters).
# Processing EXC... done (24 quarters).
# Processing EXE... done (21 quarters).
# Processing EXPE... done (24 quarters).
# Processing EXPD... done (24 quarters).
# Processing EXR... done (24 quarters).
# Processing XOM... done (24 quarters).
# Processing FFIV... done (24 quarters).
# Processing FDS... done (24 quarters).
# Processing FICO... done (24 quarters).
# Processing FAST... done (24 quarters).
# Processing FRT... done (24 quarters).
# Processing FDX... done (24 quarters).
# Processing FIS... done (24 quarters).
# Processing FITB... done (24 quarters).
# Processing FSLR... done (24 quarters).
# Processing FE... done (24 quarters).
# Processing FISV... done (24 quarters).
# Processing F... done (24 quarters).
# Processing FTNT... done (24 quarters).
# Processing FTV... done (24 quarters).
# Processing FOXA... done (24 quarters).
# Processing FOX... done (24 quarters).
# Processing BEN... done (24 quarters).
# Processing FCX... done (24 quarters).
# Processing GRMN... done (24 quarters).
# Processing IT... done (24 quarters).
# Processing GE... done (24 quarters).
# Processing GEHC... done (14 quarters).
# Processing GEV... done (9 quarters).
# Processing GEN... done (24 quarters).
# Processing GNRC... done (24 quarters).
# Processing GD... done (24 quarters).
# Processing GIS... done (24 quarters).
# Processing GM... done (24 quarters).
# Processing GPC... done (24 quarters).
# Processing GILD... done (24 quarters).
# Processing GPN... done (24 quarters).
# Processing GL... done (24 quarters).
# Processing GDDY... done (24 quarters).
# Processing GS... done (24 quarters).
# Processing HAL... done (24 quarters).
# Processing HIG... done (24 quarters).
# Processing HAS... done (24 quarters).
# Processing HCA... done (24 quarters).
# Processing DOC... done (24 quarters).
# Processing HSIC... done (24 quarters).
# Processing HSY... done (24 quarters).
# Processing HPE... done (24 quarters).
# Processing HLT... done (24 quarters).
# Processing HD... done (24 quarters).
# Processing HON... done (24 quarters).
# Processing HRL... done (24 quarters).
# Processing HST... done (24 quarters).
# Processing HWM... done (24 quarters).
# Processing HPQ... done (24 quarters).
# Processing HUBB... done (24 quarters).
# Processing HUM... done (24 quarters).
# Processing HBAN... done (24 quarters).
# Processing HII... done (24 quarters).
# Processing IBM... done (24 quarters).
# Processing IEX... done (24 quarters).
# Processing IDXX... done (24 quarters).
# Processing ITW... done (24 quarters).
# Processing INCY... done (24 quarters).
# Processing IR... done (24 quarters).
# Processing PODD... done (24 quarters).
# Processing INTC... done (24 quarters).
# Processing IBKR... done (24 quarters).
# Processing ICE... done (24 quarters).
# Processing IFF... done (24 quarters).
# Processing IP... done (24 quarters).
# Processing INTU... done (24 quarters).
# Processing ISRG... done (0 quarters).
# Processing IVZ... done (24 quarters).
# Processing INVH... done (24 quarters).
# Processing IQV... done (24 quarters).
# Processing IRM... done (24 quarters).
# Processing JBHT... done (24 quarters).
# Processing JBL... done (24 quarters).
# Processing JKHY... done (24 quarters).
# Processing J... done (24 quarters).
# Processing JNJ... done (24 quarters).
# Processing JCI... done (24 quarters).
# Processing JPM... done (24 quarters).
# Processing KVUE... done (12 quarters).
# Processing KDP... done (24 quarters).
# Processing KEY... done (24 quarters).
# Processing KEYS... done (24 quarters).
# Processing KMB... done (24 quarters).
# Processing KIM... done (24 quarters).
# Processing KMI... done (24 quarters).
# Processing KKR... done (24 quarters).
# Processing KLAC... done (24 quarters).
# Processing KHC... done (24 quarters).
# Processing KR... done (24 quarters).
# Processing LHX... done (24 quarters).
# Processing LH... done (24 quarters).
# Processing LRCX... done (24 quarters).
# Processing LVS... done (24 quarters).
# Processing LDOS... done (24 quarters).
# Processing LEN... done (24 quarters).
# Processing LII... done (24 quarters).
# Processing LLY... done (24 quarters).
# Processing LIN... done (24 quarters).
# Processing LYV... done (24 quarters).
# Processing LMT... done (24 quarters).
# Processing L... done (24 quarters).
# Processing LOW... done (24 quarters).
# Processing LULU... done (24 quarters).
# Processing LITE... done (24 quarters).
# Processing LYB... done (24 quarters).
# Processing MTB... done (24 quarters).
# Processing MPC... done (24 quarters).
# Processing MAR... done (24 quarters).
# Processing MRSH... done (24 quarters).
# Processing MLM... done (24 quarters).
# Processing MAS... done (24 quarters).
# Processing MA... done (24 quarters).
# Processing MKC... done (24 quarters).
# Processing MCD... done (24 quarters).
# Processing MCK... done (24 quarters).
# Processing MDT... done (24 quarters).
# Processing MRK... done (24 quarters).
# Processing META... done (24 quarters).
# Processing MET... done (24 quarters).
# Processing MTD... done (24 quarters).
# Processing MGM... done (24 quarters).
# Processing MCHP... done (24 quarters).
# Processing MU... done (24 quarters).
# Processing MSFT... done (24 quarters).
# Processing MAA... done (24 quarters).
# Processing MRNA... done (24 quarters).
# Processing TAP... done (24 quarters).
# Processing MDLZ... done (24 quarters).
# Processing MPWR... done (24 quarters).
# Processing MNST... done (24 quarters).
# Processing MCO... done (24 quarters).
# Processing MS... done (24 quarters).
# Processing MOS... done (24 quarters).
# Processing MSI... done (24 quarters).
# Processing MSCI... done (24 quarters).
# Processing NDAQ... done (24 quarters).
# Processing NTAP... done (24 quarters).
# Processing NFLX... done (24 quarters).
# Processing NEM... done (24 quarters).
# Processing NWSA... done (24 quarters).
# Processing NWS... done (24 quarters).
# Processing NEE... done (24 quarters).
# Processing NKE... done (24 quarters).
# Processing NI... done (24 quarters).
# Processing NDSN... done (24 quarters).
# Processing NSC... done (24 quarters).
# Processing NTRS... done (24 quarters).
# Processing NOC... done (24 quarters).
# Processing NCLH... done (24 quarters).
# Processing NRG... done (24 quarters).
# Processing NUE... done (24 quarters).
# Processing NVDA... done (24 quarters).
# Processing NVR... done (24 quarters).
# Processing NXPI... done (24 quarters).
# Processing ORLY... done (24 quarters).
# Processing OXY... done (24 quarters).
# Processing ODFL... done (24 quarters).
# Processing OMC... done (24 quarters).
# Processing ON... done (24 quarters).
# Processing OKE... done (24 quarters).
# Processing ORCL... done (24 quarters).
# Processing OTIS... done (24 quarters).
# Processing PCAR... done (24 quarters).
# Processing PKG... done (24 quarters).
# Processing PLTR... done (23 quarters).
# Processing PANW... done (24 quarters).
# Processing PSKY... done (24 quarters).
# Processing PH... done (24 quarters).
# Processing PAYX... done (24 quarters).
# Processing PYPL... done (24 quarters).
# Processing PNR... done (24 quarters).
# Processing PEP... done (24 quarters).
# Processing PFE... done (24 quarters).
# Processing PCG... done (24 quarters).
# Processing PM... done (24 quarters).
# Processing PSX... done (24 quarters).
# Processing PNW... done (24 quarters).
# Processing PNC... done (24 quarters).
# Processing POOL... done (24 quarters).
# Processing PPG... done (24 quarters).
# Processing PPL... done (24 quarters).
# Processing PFG... done (24 quarters).
# Processing PG... done (24 quarters).
# Processing PGR... done (24 quarters).
# Processing PLD... done (24 quarters).
# Processing PRU... done (24 quarters).
# Processing PEG... done (24 quarters).
# Processing PTC... done (24 quarters).
# Processing PSA... done (24 quarters).
# Processing PHM... done (24 quarters).
# Processing PWR... done (24 quarters).
# Processing QCOM... done (24 quarters).
# Processing DGX... done (24 quarters).
# Processing Q... done (2 quarters).
# Processing RL... done (24 quarters).
# Processing RJF... done (24 quarters).
# Processing RTX... done (24 quarters).
# Processing O... done (24 quarters).
# Processing REG... done (24 quarters).
# Processing REGN... done (24 quarters).
# Processing RF... done (24 quarters).
# Processing RSG... done (24 quarters).
# Processing RMD... done (24 quarters).
# Processing RVTY... done (24 quarters).
# Processing HOOD... done (19 quarters).
# Processing ROK... done (24 quarters).
# Processing ROL... done (24 quarters).
# Processing ROP... done (24 quarters).
# Processing ROST... done (24 quarters).
# Processing RCL... done (24 quarters).
# Processing SPGI... done (24 quarters).
# Processing CRM... done (24 quarters).
# Processing SNDK... done (5 quarters).
# Processing SBAC... done (24 quarters).
# Processing SLB... done (24 quarters).
# Processing STX... done (24 quarters).
# Processing SRE... done (24 quarters).
# Processing NOW... done (24 quarters).
# Processing SHW... done (24 quarters).
# Processing SPG... done (24 quarters).
# Processing SWKS... done (24 quarters).
# Processing SJM... done (24 quarters).
# Processing SW... done (24 quarters).
# Processing SNA... done (24 quarters).
# Processing SOLV... done (9 quarters).
# Processing SO... done (24 quarters).
# Processing LUV... done (24 quarters).
# Processing SWK... done (24 quarters).
# Processing SBUX... done (24 quarters).
# Processing STT... done (24 quarters).
# Processing STLD... done (24 quarters).
# Processing STE... done (24 quarters).
# Processing SYK... done (24 quarters).
# Processing SMCI... done (24 quarters).
# Processing SYF... done (24 quarters).
# Processing SNPS... done (24 quarters).
# Processing SYY... done (24 quarters).
# Processing TMUS... done (24 quarters).
# Processing TROW... done (24 quarters).
# Processing TTWO... done (24 quarters).
# Processing TPR... done (24 quarters).
# Processing TRGP... done (24 quarters).
# Processing TGT... done (24 quarters).
# Processing TEL... done (24 quarters).
# Processing TDY... done (24 quarters).
# Processing TER... done (24 quarters).
# Processing TSLA... done (24 quarters).
# Processing TXN... done (24 quarters).
# Processing TPL... done (24 quarters).
# Processing TXT... done (24 quarters).
# Processing TMO... done (24 quarters).
# Processing TJX... done (24 quarters).
# Processing TKO... done (24 quarters).
# Processing TTD... done (24 quarters).
# Processing TSCO... done (24 quarters).
# Processing TT... done (24 quarters).
# Processing TDG... done (24 quarters).
# Processing TRV... done (24 quarters).
# Processing TRMB... done (24 quarters).
# Processing TFC... done (24 quarters).
# Processing TYL... done (24 quarters).
# Processing TSN... done (24 quarters).
# Processing USB... done (24 quarters).
# Processing UBER... done (24 quarters).
# Processing UDR... done (24 quarters).
# Processing ULTA... done (24 quarters).
# Processing UNP... done (24 quarters).
# Processing UAL... done (24 quarters).
# Processing UPS... done (24 quarters).
# Processing URI... done (24 quarters).
# Processing UNH... done (24 quarters).
# Processing UHS... done (24 quarters).
# Processing VLO... done (24 quarters).
# Processing VEEV... done (24 quarters).
# Processing VTR... done (24 quarters).
# Processing VLTO... done (10 quarters).
# Processing VRSN... done (24 quarters).
# Processing VRSK... done (24 quarters).
# Processing VZ... done (24 quarters).
# Processing VRTX... done (24 quarters).
# Processing VRT... done (24 quarters).
# Processing VTRS... done (24 quarters).
# Processing VICI... done (24 quarters).
# Processing V... done (24 quarters).
# Processing VST... done (24 quarters).
# Processing VMC... done (24 quarters).
# Processing WRB... done (24 quarters).
# Processing GWW... done (24 quarters).
# Processing WAB... done (24 quarters).
# Processing WMT... done (24 quarters).
# Processing DIS... done (24 quarters).
# Processing WBD... done (24 quarters).
# Processing WM... done (24 quarters).
# Processing WAT... done (24 quarters).
# Processing WEC... done (24 quarters).
# Processing WFC... done (24 quarters).
# Processing WELL... done (24 quarters).
# Processing WST... done (24 quarters).
# Processing WDC... done (24 quarters).
# Processing WY... done (24 quarters).
# Processing WSM... done (24 quarters).
# Processing WMB... done (24 quarters).
# Processing WTW... done (24 quarters).
# Processing WDAY... done (24 quarters).
# Processing WYNN... done (24 quarters).
# Processing XEL... done (24 quarters).
# Processing XYL... done (24 quarters).
# Processing YUM... done (24 quarters).
# Processing ZBRA... done (24 quarters).
# Processing ZBH... done (24 quarters).
# Processing ZTS... done (24 quarters).
# Raw dataset shape: (11889, 12)
# Step 3: Cleaning data...
# After cleaning: (11212, 14)
# Step 4: K-means clustering...
# Optimal clusters: 3
# Step 5: Walk-forward logistic regression (predicting 6-month excess return)...
# Test quarter 2023-06-30 23:59:59.999999999: Accuracy = 0.532
# Test quarter 2023-09-30 23:59:59.999999999: Accuracy = 0.509
# Test quarter 2023-12-31 23:59:59.999999999: Accuracy = 0.563
# Test quarter 2024-03-31 23:59:59.999999999: Accuracy = 0.556
# Test quarter 2024-06-30 23:59:59.999999999: Accuracy = 0.524
# Test quarter 2024-09-30 23:59:59.999999999: Accuracy = 0.590
# Test quarter 2024-12-31 23:59:59.999999999: Accuracy = 0.563
# Test quarter 2025-03-31 23:59:59.999999999: Accuracy = 0.524
# Test quarter 2025-06-30 23:59:59.999999999: Accuracy = 0.567
# Test quarter 2025-09-30 23:59:59.999999999: Accuracy = 0.518
# Test quarter 2025-12-31 23:59:59.999999999: Accuracy = 0.521
# Test quarter 2026-03-31 23:59:59.999999999: Accuracy = 0.532
# Model evaluation:
#   accuracy: 0.542
#   precision: 0.453
#   recall: 0.494
#   f1: 0.472
#   roc_auc: 0.548
# Step 6: Generate cluster-aware ranking for most recent quarter...
#
# Top 5 stocks per cluster (quarter = 2026-03-31):
#
# Cluster 0:
# ticker  pred_proba  trailing_pe
#    HST    0.520944    24.781555
#    CRM    0.520734    24.970404
#    ACN    0.520036    25.607122
#   FOXA    0.519957    25.680480
#    OKE    0.519269    26.324681
#
# Cluster 1:
# ticker  pred_proba  trailing_pe
#     IR    0.461355   137.736593
#   COIN    0.461189   138.543410
#   GRMN    0.461114   138.906192
#    ADI    0.460916   139.876107
#   PANW    0.460610   141.388136
#
# Cluster 2:
# ticker  pred_proba  trailing_pe
#      T    0.605645     1.306871
#  CMCSA    0.604335     1.419142
#   NVDA    0.603957     1.452444
#    BAC    0.602462     1.588907
#   GOOG    0.596861     2.168859
#
# Ranking saved to 'stock_ranking_latest_quarter.csv'
# Full dataset saved to 'full_dataset_with_clusters.csv'
